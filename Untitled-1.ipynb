# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import shutil
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator, img_to_array, array_to_img
# Create a new directory
base_dir = "base_dir"
base_msk = "base_msk"

# %%
parent_dir = "/home/AhsenAliAsif/Desktop/Malik/dataverse_files/"
path = os.path.join(parent_dir, base_dir)
os.mkdir(path)

# [CREATE FOLDERS INSIDE THE BASE DIRECTORY]

# now we create 7 folders inside 'base_dir':

# train_dir
# nv
# mel
# bkl
# bcc
# akiec
# vasc
# df

# val_dir
# nv
# mel
# bkl
# bcc
# akiec
# vasc
# df

# create a path to 'base_dir' to which we will join the names of the new folders
# train_dir
train_dir = os.path.join(path, 'train_dir')
os.mkdir(train_dir)

# val_dir
val_dir = os.path.join(path, 'val_dir')
os.mkdir(val_dir)

# [CREATE FOLDERS INSIDE THE TRAIN, VALIDATION AND TEST FOLDERS]
# Inside each folder we create seperate folders for each class

# create new folders inside train_dir
nv = os.path.join(train_dir, 'nv')
os.mkdir(nv)
mel = os.path.join(train_dir, 'mel')
os.mkdir(mel)
bkl = os.path.join(train_dir, 'bkl')
os.mkdir(bkl)
bcc = os.path.join(train_dir, 'bcc')
os.mkdir(bcc)
akiec = os.path.join(train_dir, 'akiec')
os.mkdir(akiec)
vasc = os.path.join(train_dir, 'vasc')
os.mkdir(vasc)
df = os.path.join(train_dir, 'df')
os.mkdir(df)

# create new folders inside val_dir
nv = os.path.join(val_dir, 'nv')
os.mkdir(nv)
mel = os.path.join(val_dir, 'mel')
os.mkdir(mel)
bkl = os.path.join(val_dir, 'bkl')
os.mkdir(bkl)
bcc = os.path.join(val_dir, 'bcc')
os.mkdir(bcc)
akiec = os.path.join(val_dir, 'akiec')
os.mkdir(akiec)
vasc = os.path.join(val_dir, 'vasc')
os.mkdir(vasc)
df = os.path.join(val_dir, 'df')
os.mkdir(df)

# %%
parent_dir = "/home/AhsenAliAsif/Desktop/Malik/dataverse_files/"
path = os.path.join(parent_dir, base_msk)
os.mkdir(path)

# [CREATE FOLDERS INSIDE THE BASE DIRECTORY]

# now we create 7 folders inside 'base_dir':

# train_msk
# nv
# mel
# bkl
# bcc
# akiec
# vasc
# df

# val_msk
# nv
# mel
# bkl
# bcc
# akiec
# vasc
# df

# create a path to 'base_dir' to which we will join the names of the new folders
# train_dir
train_msk = os.path.join(path, 'train_msk')
os.mkdir(train_msk)

# val_dir
val_msk = os.path.join(path, 'val_msk')
os.mkdir(val_msk)

# [CREATE FOLDERS INSIDE THE TRAIN, VALIDATION AND TEST FOLDERS]
# Inside each folder we create seperate folders for each class

# create new folders inside train_dir
nv = os.path.join(train_msk, 'nv')
os.mkdir(nv)
mel = os.path.join(train_msk, 'mel')
os.mkdir(mel)
bkl = os.path.join(train_msk, 'bkl')
os.mkdir(bkl)
bcc = os.path.join(train_msk, 'bcc')
os.mkdir(bcc)
akiec = os.path.join(train_msk, 'akiec')
os.mkdir(akiec)
vasc = os.path.join(train_msk, 'vasc')
os.mkdir(vasc)
df = os.path.join(train_msk, 'df')
os.mkdir(df)

# create new folders inside val_dir
nv = os.path.join(val_msk, 'nv')
os.mkdir(nv)
mel = os.path.join(val_msk, 'mel')
os.mkdir(mel)
bkl = os.path.join(val_msk, 'bkl')
os.mkdir(bkl)
bcc = os.path.join(val_msk, 'bcc')
os.mkdir(bcc)
akiec = os.path.join(val_msk, 'akiec')
os.mkdir(akiec)
vasc = os.path.join(val_msk, 'vasc')
os.mkdir(vasc)
df = os.path.join(val_msk, 'df')
os.mkdir(df)

# %%
# read text file into pandas DataFrame
df_data = pd.read_csv("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/HAM10000_metadata.txt", sep=',')
#df_data = pd.read_csv('E:/dataverse_files/HAM10000_metadata.csv')
df_data.head()
print(df_data.head())
# this will tell us how many images are associated with each lesion_id
df = df_data.groupby('lesion_id').count()
# now we filter out lesion_id's that have only one image associated with it
df = df[df['image_id'] == 1]
df.reset_index(inplace=True)
df.head()
print(df.head())
df.shape

# here we identify lesion_id's that have duplicate images and those that have only
# one image.

def identify_duplicates(x):
    unique_list = list(df['lesion_id'])

    if x in unique_list:
        return 'no_duplicates'
    else:
        return 'has_duplicates'


# create a new colum that is a copy of the lesion_id column
df_data['duplicates'] = df_data['lesion_id']
# apply the function to this new column
df_data['duplicates'] = df_data['duplicates'].apply(identify_duplicates)

df_data.head()
print(df_data.head())
df_data.shape
print(df_data['duplicates'].value_counts())
# now we filter out images that don't have duplicates
df = df_data[df_data['duplicates'] == "no_duplicates"]
df.shape
df.drop('duplicates', inplace=True, axis=1)
print(df.head())
print(df.shape)


# now we create a val set using df because we are sure that none of these images
# have augmented duplicates in the train set
y = df['dx']
_, df_val = train_test_split(df, test_size=0.17, random_state=101, stratify=y)
print(df_val.shape)


# This set will be df_data excluding all rows that are in the val set

# This function identifies if an image is part of the train
# or val set.
def identify_val_rows(x):
    # create a list of all the lesion_id's in the val set
    val_list = list(df_val['image_id'])

    if str(x) in val_list:
        return 'val'
    else:
        return 'train'


# identify train and val rows

# create a new colum that is a copy of the image_id column
df_data['train_or_val'] = df_data['image_id']
# apply the function to this new column
df_data['train_or_val'] = df_data['train_or_val'].apply(identify_val_rows)

# filter out train rows
df_train = df_data[df_data['train_or_val'] == 'train']

print(len(df_train))
print(len(df_val))
print(df_train['dx'].value_counts())
print(df_val['dx'].value_counts())
# Set the image_id as the index in df_data
df_data.set_index('image_id', inplace=True)


# Get a list of images in each of the two folders

folder_1 = os.listdir("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/HAM10000_images_part_1")

folder_2 = os.listdir("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/HAM10000_segmentations_lesion_tschandl/HAM10000_segmentations_lesion_tschandl")
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset
# 0  vidir_modern
# 1  vidir_modern
# 2  vidir_modern
# 3  vidir_modern
# 4  vidir_modern
#      lesion_id  image_id  dx  dx_type  age  sex  localization  dataset
# 0  HAM_0000001         1   1        1    1    1             1        1
# 1  HAM_0000003         1   1        1    1    1             1        1
# 2  HAM_0000004         1   1        1    1    1             1        1
# 3  HAM_0000007         1   1        1    1    1             1        1
# 4  HAM_0000008         1   1        1    1    1             1        1
# ...

# %%
# Get a list of train and val images
train_list = list(df_train['image_id'])
val_list = list(df_val['image_id'])

# Transfer the train images

for image in train_list:

    fname = image + '.jpg'
    label = df_data.loc[image, 'dx']

    if fname in folder_1:
        # source path to image
        src = os.path.join("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/HAM10000_images_part_1", fname)
        # destination path to image
        dst = os.path.join(train_dir, label, fname)
        # copy the image from the source to the destination
        shutil.copyfile(src, dst)

# Transfer the val images

for image in val_list:

    fname = image + '.jpg'
    label = df_data.loc[image, 'dx']

    if fname in folder_1:
        # source path to image
        src = os.path.join("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/HAM10000_images_part_1", fname)
        # destination path to image
        dst = os.path.join(val_dir, label, fname)
        # copy the image from the source to the destination
        shutil.copyfile(src, dst)

# %%
# Get a list of train and val images
train_list = list(df_train['image_id'])
val_list = list(df_val['image_id'])

# Transfer the train images

for image in train_list:
    fname = image + '_segmentation.png'
    label = df_data.loc[image, 'dx']

    if fname in folder_2:
        # source path to image
        src = os.path.join("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/HAM10000_segmentations_lesion_tschandl/HAM10000_segmentations_lesion_tschandl/", fname)
        # destination path to image
        dst = os.path.join(train_msk, label, fname)
        # copy the image from the source to the destination
        shutil.copyfile(src, dst)

# Transfer the val images

for image in val_list:

    fname = image + '_segmentation.png'
    label = df_data.loc[image, 'dx']

    if fname in folder_2:
        # source path to image
        src = os.path.join("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/HAM10000_segmentations_lesion_tschandl/HAM10000_segmentations_lesion_tschandl/", fname)
        # destination path to image
        dst = os.path.join(val_msk, label, fname)
        # copy the image from the source to the destination
        shutil.copyfile(src, dst)

# %%
#Display ids for images and masks.
data_size = len(os.listdir("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_dir/train_dir/df"))
img_ids = sorted(os.listdir("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_dir/train_dir/df"))
mask_ids = sorted(os.listdir("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_msk/train_msk/df"))
#Generate some random index.
rnd_ind = list(np.random.choice(data_size,8))
for i in rnd_ind:
    print("image id: '{}' -- Corressponding Mask id '{}'".format(img_ids[i], mask_ids[i]))
# Out:
# image id: 'ISIC_0029783.jpg' -- Corressponding Mask id 'ISIC_0029783_segmentation.png'
# image id: 'ISIC_0030021.jpg' -- Corressponding Mask id 'ISIC_0030021_segmentation.png'
# image id: 'ISIC_0033808.jpg' -- Corressponding Mask id 'ISIC_0033808_segmentation.png'
# image id: 'ISIC_0031372.jpg' -- Corressponding Mask id 'ISIC_0031372_segmentation.png'
# image id: 'ISIC_0028880.jpg' -- Corressponding Mask id 'ISIC_0028880_segmentation.png'
# image id: 'ISIC_0030757.jpg' -- Corressponding Mask id 'ISIC_0030757_segmentation.png'
# image id: 'ISIC_0029973.jpg' -- Corressponding Mask id 'ISIC_0029973_segmentation.png'
# image id: 'ISIC_0031309.jpg' -- Corressponding Mask id 'ISIC_0031309_segmentation.png'

# %%
#Pick the 1553th car&mask ids from ids lists.
n = 15
img_id = img_ids[n]
mask_id = mask_ids[n]
#Load imag&mask images using thier ids.
imag = load_img("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_dir/train_dir/df/" + img_id)
mask = load_img("/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_msk/train_msk/df/"+ mask_id)
print("Image Size: ", imag.size)
print("Mask Size: ", mask.size)
#Plot them.
fig, ax = plt.subplots(1, 2, figsize=(10,10))
fig.subplots_adjust(hspace=.1, wspace=.01)
ax[0].imshow(imag)
ax[0].axis('off')
ax[0].title.set_text('lesion Image')
ax[1].imshow(mask)
ax[1].axis('off')
ax[1].title.set_text('lesion Mask')
# Out:
# Image Size:  (600, 450)
# Mask Size:  (600, 450)

# %%
# Check how many train images we now have in each folder.
# This is the original images plus the augmented images.
print("train data ")
print(len(os.listdir('base_dir/train_dir/nv')))
print(len(os.listdir('base_dir/train_dir/mel')))
print(len(os.listdir('base_dir/train_dir/bkl')))
print(len(os.listdir('base_dir/train_dir/bcc')))
print(len(os.listdir('base_dir/train_dir/akiec')))
print(len(os.listdir('base_dir/train_dir/vasc')))
print(len(os.listdir('base_dir/train_dir/df')))

# Check how many val images we have in each folder.
print("validfation data ")

print(len(os.listdir('base_dir/val_dir/nv')))
print(len(os.listdir('base_dir/val_dir/mel')))
print(len(os.listdir('base_dir/val_dir/bkl')))
print(len(os.listdir('base_dir/val_dir/bcc')))
print(len(os.listdir('base_dir/val_dir/akiec')))
print(len(os.listdir('base_dir/val_dir/vasc')))
print(len(os.listdir('base_dir/val_dir/df')))



# Check how many train images we now have in each folder.
# This is the original images plus the augmented images.
print("train data ")
print(len(os.listdir('base_msk/train_msk/nv')))
print(len(os.listdir('base_msk/train_msk/mel')))
print(len(os.listdir('base_msk/train_msk/bkl')))
print(len(os.listdir('base_msk/train_msk/bcc')))
print(len(os.listdir('base_msk/train_msk/akiec')))
print(len(os.listdir('base_msk/train_msk/vasc')))
print(len(os.listdir('base_msk/train_msk/df')))

# Check how many val images we have in each folder.
print("validfation data ")

print(len(os.listdir('base_msk/val_msk/nv')))
print(len(os.listdir('base_msk/val_msk/mel')))
print(len(os.listdir('base_msk/val_msk/bkl')))
print(len(os.listdir('base_msk/val_msk/bcc')))
print(len(os.listdir('base_msk/val_msk/akiec')))
print(len(os.listdir('base_msk/val_msk/vasc')))
print(len(os.listdir('base_msk/val_msk/df')))
# Out:
# train data
# 5954
# 1074
# 1024
# 484
# 301
# 131
# 109
# validfation data
# 751
# 39
# 75
# 30
# 26
# 11
# 6
# train data
# 5954
# 1074
# 1024
# 484
# 301
# 131
# 109
# validfation data
# 751
# 39
# 75
# 30
# 26
# 11
# 6

# %%
from glob import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %%
img_size = [224, 224]

train_dataSet = '/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_dir/train_dir'
test_dataSet = '/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_dir/val_dir'
train_mask = '/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_msk/train_msk'
test_mask = '/home/AhsenAliAsif/Desktop/Malik/dataverse_files/base_msk/val_msk'

folders = glob(train_dataSet+'/*')
resnet50 = ResNet50(input_shape = img_size + [3], weights = 'imagenet', include_top = False)
for layer in resnet50.layers:
  layer.trainable = False


x = Flatten()(resnet50.output)
prediction = Dense(7, kernel_regularizer=regularizers.L2(l2=1e-4), activation='softmax')(x)

model = Model(inputs = resnet50.input, outputs = prediction)
model.summary()

model.compile(loss='squared_hinge', optimizer='adam',
metrics=['accuracy'])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
# ...

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255) 
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_generator = train_datagen.flow_from_directory(
train_dataSet,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')


test_generator = train_datagen.flow_from_directory(
test_dataSet,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')
print(train_generator.class_indices)

print(test_generator.class_indices)
# Out:
# Found 9077 images belonging to 7 classes.
# Found 938 images belonging to 7 classes.
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
#In fit_generator(), you don't pass the x and y directly, instead they come from a generator.
history = model.fit_generator(
    train_generator,
    steps_per_epoch=150,
    epochs=10,
    validation_data=test_generator)
# Out:
# Epoch 1/10
# /tmp/ipykernel_1934396/967263696.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 2022-12-16 10:59:26.766039: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 102760448 exceeds 10% of free system memory.
# 2022-12-16 10:59:26.881480: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 102760448 exceeds 10% of free system memory.
# 2022-12-16 10:59:26.959348: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 106463232 exceeds 10% of free system memory.
# 2022-12-16 10:59:27.012792: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 102760448 exceeds 10% of free system memory.
# 2022-12-16 10:59:27.038465: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 102760448 exceeds 10% of free system memory.
# ...
